# %%
import os
import json
import pandas as pd

# %%
def process_job_search(folder_path):
    #an empty list to store the JSON data
    json_data_list = []

    #get the list of files in the folder
    file_list = os.listdir(folder_path)

    #iterate over the files
    for file_name in file_list:
        if file_name.endswith('.json'):  # Check if the file is a JSON file
            file_path = os.path.join(folder_path, file_name)  # Construct the file path
            with open(file_path, 'r') as file:
                json_data = json.load(file)  # Load the JSON data
                jobs_results = json_data.get("jobs_results", [])  # Get the list of job results
                search_parameters = json_data.get("search_parameters", {})  # Get the search parameters

                #iterate over the jobs results
                for job_result in jobs_results:
                    job_result["searching keyword"] = search_parameters.get("q", "")  # Add the 'q' value to the job result

                    job_result["search_metadata_id"] = json_data.get("search_metadata", {}).get("id", "")  # Add search_metadata_id to the job result

                    #extract Qualifications and Responsibilities from job_highlights
                    job_highlights = job_result.get("job_highlights", [])
                    qualifications = ""
                    responsibilities = ""

                    for highlight in job_highlights:
                        title = highlight.get("title", "")
                        items = highlight.get("items", [])

                        if title == "Qualifications":
                            qualifications = " ".join(items)
                        elif title == "Responsibilities":
                            responsibilities = " ".join(items)

                    job_result["Qualifications"] = qualifications
                    job_result["Responsibilities"] = responsibilities

                    #process the description
                    description = job_result.get("description", "")
                    description = description.replace("\n", " ")  # Replace newlines with spaces
                    job_result["description"] = description

                    #extract information from detected_extensions into separate columns
                    detected_extensions = job_result.get("detected_extensions", {})
                    salary = detected_extensions.get("salary", "")
                    schedule_type = detected_extensions.get("schedule_type", "")

                    job_result["salary"] = salary
                    job_result["schedule_type"] = schedule_type

                    #append the job result to the list
                    json_data_list.append(job_result)

    #create a DataFrame from the JSON data
    df = pd.DataFrame(json_data_list)
    df = df.drop(['job_highlights', 'related_links', 'detected_extensions', 'extensions', 'search_metadata_id'], axis=1)
    df = df.rename(columns={'q': 'searching keyword'})
    df['via'] = df['via'].str.replace('via ', '')

    return df

# %%
folder_path = '../Data Set/2023-04-14-job-search/2023-04-14-job-search-location-DC'
df_DC = process_job_search(folder_path)

# %%
df_DC.head()
# Out:
#                                                title  \
# 0             Ethereum Blockchain Developer (Remote)
# 1                                Blockchain Engineer
# 2                       Blockchain Course Instructor
# 3  Python based - Blockchain developer to join ex...
# 4                Blockchain DevOps Engineer (Remote)
#
#                          company_name            location           via  \
# 0                          Ex Populus           Anywhere       Built In
# 1                               21.co     New York, NY       Greenhouse
# 2  Blockchain Institute of Technology           Anywhere       LinkedIn
# 3                              Upwork           Anywhere         Upwork
# 4                              Telnyx    United States     Startup Jobs
#
#                                          description  \
# 0  Company Overview: Ex Populus is a cutting-edge...
# 1  We are seeking a highly motivated and skilled ...
# 2  Are you a blockchain, cryptocurrency, NFT, Met...
# 3  Need someone to join our existing team to spee...
# 4  About Telnyx  At Telnyx, we’re architecting an...
#
#                                               job_id searching keyword  \
# 0  eyJqb2JfdGl0bGUiOiJFdGhlcmV1bSBCbG9ja2NoYWluIE...       block chain
# 1  eyJqb2JfdGl0bGUiOiJCbG9ja2NoYWluIEVuZ2luZWVyIi...       block chain
# 2  eyJqb2JfdGl0bGUiOiJCbG9ja2NoYWluIENvdXJzZSBJbn...       block chain
# 3  eyJqb2JfdGl0bGUiOiJQeXRob24gYmFzZWQgLSBCbG9ja2...       block chain
# 4  eyJqb2JfdGl0bGUiOiJCbG9ja2NoYWluIERldk9wcyBFbm...       block chain
#
#                                       Qualifications  \
# 0  2-3 years of Software Development experience 1...
# 1  Bachelor's or Master's degree in Computer Scie...
# 2  3+ years of experience in blockchain, cryptocu...
# 3  Candidates must be willing to sign, non-disclo...
# 4  You are a highly motivated and experienced Blo...
#
#                                     Responsibilities         salary  \
# 0  Design, maintain and deploy smart contracts fo...
# 1  As a Blockchain Engineer, you will be responsi...
# 2  Our expert technical team will provide the sup...
# 3  Will discuss details with the selected candidates  10–30 an hour
# 4  To build a best-in-class Filecoin (FIL) Mining...
#
#   schedule_type
# 0     Full-time
# 1     Full-time
# 2    Contractor
# 3    Contractor
# 4     Full-time

# %%
folder_path = '../Data Set/2023-04-14-job-search/2023-04-14-job-search-location-USA'
df_USA = process_job_search(folder_path)

# %%
df_USA.head()
# Out:
#                                                title company_name  \
# 0                Senior Blockchain Software Engineer       Truist
# 1  Get twitter accounts that are tied to blockcha...       Upwork
# 2                                 Blockchain Analyst       Allium
# 3                     Full Stack Blockchain Engineer       geojam
# 4  Blockchain Engineer - Apps Platform at Exodus ...       Exodus
#
#                location                    via  \
# 0             Anywhere            ZipRecruiter
# 1             Anywhere                  Upwork
# 2       New York, NY                      Jobs
# 3    Los Angeles, CA                 AngelList
# 4      Livermore, CA     Livermore, CA - Geebo
#
#                                          description  \
# 0  The position is described below. If you want t...
# 1  I am looking for a list of blockchain addresse...
# 2  About the role • Sherlock & Enola Holmes level...
# 3  Who We Are  Launched in 2020, Geojam is a soci...
# 4  Exodus is looking for a detail-orientated Bloc...
#
#                                               job_id searching keyword  \
# 0  eyJqb2JfdGl0bGUiOiJTZW5pb3IgQmxvY2tjaGFpbiBTb2...       block chain
# 1  eyJqb2JfdGl0bGUiOiJHZXQgdHdpdHRlciBhY2NvdW50cy...       block chain
# 2  eyJqb2JfdGl0bGUiOiJCbG9ja2NoYWluIEFuYWx5c3QiLC...       block chain
# 3  eyJqb2JfdGl0bGUiOiJGdWxsIFN0YWNrIEJsb2NrY2hhaW...       block chain
# 4  eyJqb2JfdGl0bGUiOiJCbG9ja2NoYWluIEVuZ2luZWVyIC...       block chain
#
#                                       Qualifications  \
# 0  Language Fluency: English (Required) The requi...
# 1
# 2  Ability to parse and understand EVM (and/or So...
# 3  We’re looking for a capable generalist enginee...
# 4
#
#                                     Responsibilities         salary  \
# 0  Deliver highly complex solutions with signific...
# 1
# 2  Tackling interesting problems - we are ingesti...
# 3  You will be designing and building our core so...
# 4                                                     20–28 an hour
#
#   schedule_type
# 0     Full-time
# 1    Contractor
# 2     Full-time
# 3     Full-time
# 4     Full-time

# %%
#combine the datasets
combined_df = pd.concat([df_DC, df_USA])

#reset the index of the combined DataFrame
combined_df = combined_df.reset_index(drop=True)

# %%
combined_df
# Out:
#                                                  title  \
# 0               Ethereum Blockchain Developer (Remote)
# 1                                  Blockchain Engineer
# 2                         Blockchain Course Instructor
# 3    Python based - Blockchain developer to join ex...
# 4                  Blockchain DevOps Engineer (Remote)
# ..                                                 ...
# 818  Machine Learning Engineer/ Data Scientist- NLP...
# 819  Post-Doc Researcher for Natural Language Proce...
# 820  Technical Leader - Natural Language Processing...
# 821  Lead Research Scientist, Natural Language Proc...
# 822  Research Associate  in Natural Language Proces...
#
#                            company_name              location           via  \
# 0                            Ex Populus             Anywhere       Built In
# 1                                 21.co       New York, NY       Greenhouse
# 2    Blockchain Institute of Technology             Anywhere       LinkedIn
# 3                                Upwork             Anywhere         Upwork
# 4                                Telnyx      United States     Startup Jobs
# ..                                  ...                   ...           ...
# 818                           Supportiv        Chicago, IL        KLFY Jobs
# 819                        Robert Bosch      Sunnyvale, CA          Ladders
# 820                             Kitware    Minneapolis, MN     ZipRecruiter
# 821                           Snap Inc.    Los Angeles, CA           Jooble
# 822                   SRI International     Menlo Park, CA         Snagajob
#
#                                            description  \
# 0    Company Overview: Ex Populus is a cutting-edge...
# 1    We are seeking a highly motivated and skilled ...
# 2    Are you a blockchain, cryptocurrency, NFT, Met...
# 3    Need someone to join our existing team to spee...
# 4    About Telnyx  At Telnyx, we’re architecting an...
# ..                                                 ...
# 818  First, The Data! • Over 1 million unique chat ...
# 819  Company Description  The Bosch Research and Te...
# 820  Team Description:  Our computer vision team is...
# 821  Lead Research Scientist, Natural Language Proc...
# 822  Research Associate in Natural Language Process...
#
#                                                 job_id  \
# 0    eyJqb2JfdGl0bGUiOiJFdGhlcmV1bSBCbG9ja2NoYWluIE...
# 1    eyJqb2JfdGl0bGUiOiJCbG9ja2NoYWluIEVuZ2luZWVyIi...
# 2    eyJqb2JfdGl0bGUiOiJCbG9ja2NoYWluIENvdXJzZSBJbn...
# 3    eyJqb2JfdGl0bGUiOiJQeXRob24gYmFzZWQgLSBCbG9ja2...
# 4    eyJqb2JfdGl0bGUiOiJCbG9ja2NoYWluIERldk9wcyBFbm...
# ..                                                 ...
# 818  eyJqb2JfdGl0bGUiOiJNYWNoaW5lIExlYXJuaW5nIEVuZ2...
# 819  eyJqb2JfdGl0bGUiOiJQb3N0LURvYyBSZXNlYXJjaGVyIG...
# 820  eyJqb2JfdGl0bGUiOiJUZWNobmljYWwgTGVhZGVyIC0gTm...
# 821  eyJqb2JfdGl0bGUiOiJMZWFkIFJlc2VhcmNoIFNjaWVudG...
# 822  eyJqb2JfdGl0bGUiOiJSZXNlYXJjaCBBc3NvY2lhdGUgIG...
#
#                searching keyword  \
# 0                    block chain
# 1                    block chain
# 2                    block chain
# 3                    block chain
# 4                    block chain
# ..                           ...
# 818  natural language processing
# 819  natural language processing
# 820  natural language processing
# 821  natural language processing
# 822  natural language processing
#
#                                         Qualifications  \
# 0    2-3 years of Software Development experience 1...
# 1    Bachelor's or Master's degree in Computer Scie...
# 2    3+ years of experience in blockchain, cryptocu...
# 3    Candidates must be willing to sign, non-disclo...
# 4    You are a highly motivated and experienced Blo...
# ..                                                 ...
# 818  [1 day] Take-home programming challenge [60 mi...
# 819  Ph.D. in computer science or engineering 3+ ye...
# 820  PhD in Computer Science or related field with ...
# 821  Strong technical knowledge of statistics, mach...
# 822  We are seeking a potential NLP thought leader ...
#
#                                       Responsibilities            salary  \
# 0    Design, maintain and deploy smart contracts fo...
# 1    As a Blockchain Engineer, you will be responsi...
# 2    Our expert technical team will provide the sup...
# 3    Will discuss details with the selected candidates     10–30 an hour
# 4    To build a best-in-class Filecoin (FIL) Mining...
# ..                                                 ...               ...
# 818  The role will serve as a core member within th...
# 819  Conduct research on Natural Language Processin...  100K–150K a year
# 820  Lead proposals for new funding from government...
# 821  Define and own a roadmap of large-scale resear...
# 822  Successful applicants will work as part of a t...
#
#     schedule_type
# 0       Full-time
# 1       Full-time
# 2      Contractor
# 3      Contractor
# 4       Full-time
# ..            ...
# 818    Internship
# 819     Full-time
# 820     Full-time
# 821     Full-time
# 822     Full-time
#
# [823 rows x 11 columns]

# %%
combined_df.drop_duplicates(subset=combined_df.columns.difference(['job_id']), keep='first', inplace=True)

# %%
combined_df
# Out:
#                                                  title  \
# 0               Ethereum Blockchain Developer (Remote)
# 1                                  Blockchain Engineer
# 2                         Blockchain Course Instructor
# 3    Python based - Blockchain developer to join ex...
# 4                  Blockchain DevOps Engineer (Remote)
# ..                                                 ...
# 812          Blockchain Operations - Technical Analyst
# 815               Natural Language Processing Engineer
# 816  Machine Learning Engineer/ Data Scientist- NLP...
# 818  Machine Learning Engineer/ Data Scientist- NLP...
# 820  Technical Leader - Natural Language Processing...
#
#                            company_name              location           via  \
# 0                            Ex Populus             Anywhere       Built In
# 1                                 21.co       New York, NY       Greenhouse
# 2    Blockchain Institute of Technology             Anywhere       LinkedIn
# 3                                Upwork             Anywhere         Upwork
# 4                                Telnyx      United States     Startup Jobs
# ..                                  ...                   ...           ...
# 812                      Chainlink Labs             Anywhere       LinkedIn
# 815            Brain Technologies, Inc.      San Mateo, CA          Karkidi
# 816                           Supportiv       San Jose, CA        WDHN Jobs
# 818                           Supportiv        Chicago, IL        KLFY Jobs
# 820                             Kitware    Minneapolis, MN     ZipRecruiter
#
#                                            description  \
# 0    Company Overview: Ex Populus is a cutting-edge...
# 1    We are seeking a highly motivated and skilled ...
# 2    Are you a blockchain, cryptocurrency, NFT, Met...
# 3    Need someone to join our existing team to spee...
# 4    About Telnyx  At Telnyx, we’re architecting an...
# ..                                                 ...
# 812  As a Blockchain Operations - Technical Analyst...
# 815  Responsibilities: • Learning from user interac...
# 816  First, The Data! • Over 1 million unique chat ...
# 818  First, The Data! • Over 1 million unique chat ...
# 820  Team Description:  Our computer vision team is...
#
#                                                 job_id  \
# 0    eyJqb2JfdGl0bGUiOiJFdGhlcmV1bSBCbG9ja2NoYWluIE...
# 1    eyJqb2JfdGl0bGUiOiJCbG9ja2NoYWluIEVuZ2luZWVyIi...
# 2    eyJqb2JfdGl0bGUiOiJCbG9ja2NoYWluIENvdXJzZSBJbn...
# 3    eyJqb2JfdGl0bGUiOiJQeXRob24gYmFzZWQgLSBCbG9ja2...
# 4    eyJqb2JfdGl0bGUiOiJCbG9ja2NoYWluIERldk9wcyBFbm...
# ..                                                 ...
# 812  eyJqb2JfdGl0bGUiOiJCbG9ja2NoYWluIE9wZXJhdGlvbn...
# 815  eyJqb2JfdGl0bGUiOiJOYXR1cmFsIExhbmd1YWdlIFByb2...
# 816  eyJqb2JfdGl0bGUiOiJNYWNoaW5lIExlYXJuaW5nIEVuZ2...
# 818  eyJqb2JfdGl0bGUiOiJNYWNoaW5lIExlYXJuaW5nIEVuZ2...
# 820  eyJqb2JfdGl0bGUiOiJUZWNobmljYWwgTGVhZGVyIC0gTm...
#
#                searching keyword  \
# 0                    block chain
# 1                    block chain
# 2                    block chain
# 3                    block chain
# 4                    block chain
# ..                           ...
# 812                  block chain
# 815  natural language processing
# 816  natural language processing
# 818  natural language processing
# 820  natural language processing
#
#                                         Qualifications  \
# 0    2-3 years of Software Development experience 1...
# 1    Bachelor's or Master's degree in Computer Scie...
# 2    3+ years of experience in blockchain, cryptocu...
# 3    Candidates must be willing to sign, non-disclo...
# 4    You are a highly motivated and experienced Blo...
# ..                                                 ...
# 812  Have comfort and familiarity with complex engi...
# 815  Job entails working with and requires Master’s...
# 816  [1 day] Take-home programming challenge [60 mi...
# 818  [1 day] Take-home programming challenge [60 mi...
# 820  PhD in Computer Science or related field with ...
#
#                                       Responsibilities            salary  \
# 0    Design, maintain and deploy smart contracts fo...
# 1    As a Blockchain Engineer, you will be responsi...
# 2    Our expert technical team will provide the sup...
# 3    Will discuss details with the selected candidates     10–30 an hour
# 4    To build a best-in-class Filecoin (FIL) Mining...
# ..                                                 ...               ...
# 812  As a Blockchain Operations - Technical Analyst...
# 815  Learning from user interactions with our NLP s...  160K–250K a year
# 816  The role will serve as a core member within th...
# 818  The role will serve as a core member within th...
# 820  Lead proposals for new funding from government...
#
#     schedule_type
# 0       Full-time
# 1       Full-time
# 2      Contractor
# 3      Contractor
# 4       Full-time
# ..            ...
# 812    Contractor
# 815     Full-time
# 816    Internship
# 818    Internship
# 820     Full-time
#
# [621 rows x 11 columns]

# %%
combined_df[combined_df['title'] == 'Ethereum Blockchain Developer (Remote)']
# Out:
#                                     title company_name    location       via  \
# 0  Ethereum Blockchain Developer (Remote)   Ex Populus   Anywhere   Built In
#
#                                          description  \
# 0  Company Overview: Ex Populus is a cutting-edge...
#
#                                               job_id searching keyword  \
# 0  eyJqb2JfdGl0bGUiOiJFdGhlcmV1bSBCbG9ja2NoYWluIE...       block chain
#
#                                       Qualifications  \
# 0  2-3 years of Software Development experience 1...
#
#                                     Responsibilities salary schedule_type
# 0  Design, maintain and deploy smart contracts fo...            Full-time

# %%
#extract combined_df to csv( in foloder Data Set)
combined_df.to_csv('../Data Set/combined_df.csv', index=False)
